# %%
f = open('test.txt', 'w')
f.write('hello world\n qoo loves oop')
f.close()

# %%
f = open('test.txt', 'r')
for line in f.readlines():
    print line.strip()
f.close()
# Out:
# hello world
# qoo loves oop

# %%
import pyquery
print pyquery
# Out:
# <module 'pyquery' from 'C:\Users\BIG DATA\Anaconda2\lib\site-packages\pyquery\__init__.pyc'>

# %%
import requests
from bs4 import BeautifulSoup as bs
index = 3556
for i in range(3555, 3556):
    res = requests.get('https://www.ptt.cc/bbs/NBA/index{}.html'.format(i))
    soup = bs(res.text)
    for title in soup.select('.r-ent a'):
        print title.text
# Out:
# [BOX ] Wizards 104:109 Bulls 數據
# [Live] 馬刺 VS 國王
# [BOX ] Warriors 118:112 Heat 數據
# [公告] NBA 樂透開獎
# [公告] NBA 板 開始舉辦樂透!
# [情報] 連續127場三分+絕命兩連擊！這Curry太嚇人
# [情報] 火箭昨日比賽最後7分鐘6次誤判
# [BOX ] Thunder 116:103 Mavericks 數據
# [討論] 選秀籤在交易中的價值?
# [情報] LBJ：身體比去年強10倍
# [新聞] 贏球仍不滿 魔術教練：對勇士會被轟300
# [新聞] Kerr:我們的核心都是自己培養的
# Re: [情報] LBJ：身體比去年強10倍
# [花邊] Dennis Rodman幫Skrillex MV
# [新聞] 生涯最終戰 Kobe父母竟不看？
# [討論] Curry VS Korver 連續127場三分球紀錄
# [情報] 42+7+7！過半場就敢投絕殺　Curry還是地球人嗎
# [情報] Russell：不再給教練讓我打替補的理由
# [新聞] 八字夠硬 KD放話沒在希爾頓遇過鬼

# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
print res
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.technologyreview.com/'
res = requests.get(url)
soup = BeautifulSoup(res.text)
h2 = soup.select('.hp-daily__tz__title')
for h in h2:
    print h.text
# Out:
# With Patent Suit, Illumina Looks to Tame Emerging British Rival, Oxford Nanopore
# The U.S. Energy Industry Is Charging Toward Big Carbon Reductions No Matter What the Supreme Court Does
# âBut I Was Only Joking!â Why Facebook Needs an Irony Emoji
# The Latest Boston Dynamics Creation Escapes the Lab, Roams the Snowy Woods
# Google Unveils Neural Network with âSuperhumanâ Ability to Determine the Location of Almost Any Image

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
res = requests.post(url, data = playload)
soup = BeautifulSoup(res.text)

# %%
## 字串format - %

url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d'
for i in xrange(0,4):
    print i
    print url%(i+1)
# Out:
# 0
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# 1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# 2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3
# 3
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=4

# %%
## 字串format - format

url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={}'
for i in xrange(0,4):
    print i
    print url.format(i+1)
# Out:
# 0
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# 1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# 2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3
# 3
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=4

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
res = requests.post(url, data = playload)
soup = BeautifulSoup(res.text)
div = soup.select('#print_area')[0]
trs = div.select('tr')[1:-1]
for tr in trs:
    print 'http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787067&tenderCaseNo=9786y10501
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787064&tenderCaseNo=105-02
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787056&tenderCaseNo=1042009
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787055&tenderCaseNo=M05H7230
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787054&tenderCaseNo=10510
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787053&tenderCaseNo=TRES1050105
# ...

# %%
## urljoin

from urlparse import urljoin
head = 'http://www.nba.com/curry_is_good'
tail1 = '/frontpage'
tail2 = 'updatepage'
tail3 = 'http://www.nba.com/lin_is_a_nice_guy'
print urljoin(head, tail1)
print urljoin(head, tail2)
print urljoin(head, tail3)
# Out:
# http://www.nba.com/frontpage
# http://www.nba.com/updatepage
# http://www.nba.com/lin_is_a_nice_guy

# %%
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={}'
urls = []
for i in xrange(0,4):
    urls.append(url.format(i+1))
for url in urls:
    res = requests.post(url, data = playload)
    soup = BeautifulSoup(res.text)
    div = soup.select('#print_area')[0]
    trs = div.select('tr')[1:-1]
    for tr in trs:
        print 'http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787067&tenderCaseNo=9786y10501
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787064&tenderCaseNo=105-02
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787056&tenderCaseNo=1042009
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787055&tenderCaseNo=M05H7230
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787054&tenderCaseNo=10510
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787053&tenderCaseNo=TRES1050105
# ...

# %%
##  使用 session

front_page = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
rs = requests.session()
rs.post(front_page,data=playload)
# Out:
# <Response [200]>

# %%
from math import ceil
num = soup.select('.T11b')[0].text
page_num = ceil(float(num)/100)
print page_num
# Out:
# 4.0

# %%
import requests
from bs4 import BeautifulSoup as bs
from math import ceil

front_page = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
rs = requests.session()
rs.post(front_page,data=playload)
num = soup.select('.T11b')[0].text
page_num = ceil(float(num)/100)
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={}'
urls = []
for i in xrange(0, int(num)):
    urls.append(url.format(i+1))
for url in urls:
    res = requests.post(url, data = playload)
    soup = BeautifulSoup(res.text)
    div = soup.select('#print_area')[0]
    trs = div.select('tr')[1:-1]
    for tr in trs:
        print 'http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787067&tenderCaseNo=9786y10501
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787064&tenderCaseNo=105-02
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787056&tenderCaseNo=1042009
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787055&tenderCaseNo=M05H7230
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787054&tenderCaseNo=10510
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787053&tenderCaseNo=TRES1050105
# ...

# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
print res
# Out:
# <Response [200]>

# %%
print res.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
# <head>
#   <meta charset="utf-8" />
#   <title>蘋果即時新聞｜蘋果日報｜Apple Daily</title>
#   <meta name="description" content="蘋果日報網站提供即時、快速、豐富的最新時事動態，包含國際、社會、娛樂、政治、生活、財經等最新訊息，並為您搜奇地球村萬象與趣聞，強調有圖有真相、影片最明白，讓您時時刻刻掌握天下事！" />
#   <meta name="keywords" content="蘋果日報,Apple Daily,台灣,壹傳媒,Apple, Animation news, Action News, Apple news, news,蘋果,即時,最新,蘋果新聞,新聞,壹週刊,壹電視,動新聞,即時新聞,Facebook,臉書,蘋果粉絲團,plurk,twitter,留言,分享,按讚,天氣,影音新聞,影片,影音,行動版,手機,App,Android,iphone,Mango,爆料,投稿,發票,統一發票,RSS,生活,國際,娛樂,體育,副刊,財經,股市,樂透,威力彩,社會,熱門,彩券,頭彩" />
#   <meta property="og:title" content="蘋果即時新聞｜蘋果日報｜Apple Daily"/>
#   <meta property="og:image" content="http://twimg.edgesuite.net/appledaily/images/core/logo_bg.png"/>
# ...

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.text)
domain = 'http://www.appledaily.com.tw'
list_item = soup.select('.rtddt a')
for li in list_item:
    print li.select('h1')[0].text, li.select('h2')[0].text, li.select('time')[0].text, domain + li['href']
# Out:
# 台達為美新月沙丘計畫　提供追日方案(0) 財經 18:53 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803297/台達為美新月沙丘計畫　提供追日方案
# 【鴻夏戀拍板】原來如此！傳夏普通知鴻海　...(0) 財經 18:51 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803299/【鴻夏戀拍板】原來如此！傳夏普通知鴻海　負債恐增1000億元
# 【法廣RFI】胡潤富豪榜：大中華首超美國...(0) 財經 18:50 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803300/【法廣RFI】胡潤富豪榜：大中華首超美國王健林超李嘉誠
# 【更新】六福爆內線交易弊案　集團總裁女婿...(20991) 社會 18:48 http://www.appledaily.com.tw/realtimenews/article/local/20160225/803076/【更新】六福爆內線交易弊案　集團總裁女婿遭約談
# 燈會吸睛也吸「金」！　青埔房市受惠(0) 地產 18:48 http://www.appledaily.com.tw/realtimenews/article/property/20160225/803256/燈會吸睛也吸「金」！　青埔房市受惠
# 女星用這2樣東西　竟然成了「福祿猴」(56) 搜奇 18:48 http://www.appledaily.com.tw/realtimenews/article/strange/20160225/803283/女星用這2樣東西　竟然成了「福祿猴」
# 【更新】12歲女童染性病　案情竟然超展開(96653) 社會 18:46 http://www.appledaily.com.tw/realtimenews/article/local/20160225/803054/【更新】12歲女童染性病　案情竟然超展開
# ...

# %%
import pandas as pd

domain = 'http://www.appledaily.com.tw'
ary = []
for li in list_item:
    ary.append({'title':li.select('h1')[0].text, \
                'category':li.select('h2')[0].text, \
                'time':li.select('time')[0].text, \
                'url':domain + li['href']})

# %%
import pandas as pd

domain = 'http://www.appledaily.com.tw'
ary = []
for li in list_item:
    print li.select('h1')[0].text,li.select('h2')[0].text, li.select('time')[0].text, domain + li['href']
# Out:
# 台達為美新月沙丘計畫　提供追日方案(0) 財經 18:53 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803297/台達為美新月沙丘計畫　提供追日方案
# 【鴻夏戀拍板】原來如此！傳夏普通知鴻海　...(0) 財經 18:51 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803299/【鴻夏戀拍板】原來如此！傳夏普通知鴻海　負債恐增1000億元
# 【法廣RFI】胡潤富豪榜：大中華首超美國...(0) 財經 18:50 http://www.appledaily.com.tw/realtimenews/article/finance/20160225/803300/【法廣RFI】胡潤富豪榜：大中華首超美國王健林超李嘉誠
# 【更新】六福爆內線交易弊案　集團總裁女婿...(20991) 社會 18:48 http://www.appledaily.com.tw/realtimenews/article/local/20160225/803076/【更新】六福爆內線交易弊案　集團總裁女婿遭約談
# 燈會吸睛也吸「金」！　青埔房市受惠(0) 地產 18:48 http://www.appledaily.com.tw/realtimenews/article/property/20160225/803256/燈會吸睛也吸「金」！　青埔房市受惠
# 女星用這2樣東西　竟然成了「福祿猴」(56) 搜奇 18:48 http://www.appledaily.com.tw/realtimenews/article/strange/20160225/803283/女星用這2樣東西　竟然成了「福祿猴」
# 【更新】12歲女童染性病　案情竟然超展開(96653) 社會 18:46 http://www.appledaily.com.tw/realtimenews/article/local/20160225/803054/【更新】12歲女童染性病　案情竟然超展開
# ...

# %%
print ary[0]['title']
# Out:
# 台達為美新月沙丘計畫　提供追日方案(0)

# %%
df = pd.DataFrame(ary)
df
# Out:
#    category   time                           title  \
# 0        財經  18:53            台達為美新月沙丘計畫　提供追日方案(0)
# 1        財經  18:51      【鴻夏戀拍板】原來如此！傳夏普通知鴻海　...(0)
# 2        財經  18:50      【法廣RFI】胡潤富豪榜：大中華首超美國...(0)
# 3        社會  18:48  【更新】六福爆內線交易弊案　集團總裁女婿...(20991)
# 4        地產  18:48            燈會吸睛也吸「金」！　青埔房市受惠(0)
# 5        搜奇  18:48          女星用這2樣東西　竟然成了「福祿猴」(56)
# 6        社會  18:46     【更新】12歲女童染性病　案情竟然超展開(96653)
# 7        政治  18:46     郁慕明臉書諷「轉型正義」　酸說「乾脆把故...(98)
# 8        政治  18:46         陸客減少？　陸委會：較去年同期增加9%(20)
# 9        國際  18:45     【法廣RFI】強生嬰兒爽身粉致癌 判賠7...(16)
# 10       社會  18:43          【更新】路面爆大窟窿　大卡車破輪(1379)
# 11       政治  18:42       徐永明批柯建銘壟斷資訊　柯辦用這招反制(7191)
# 12       國際  18:40     ​陸一年查封近5千網站　自誇執法「成效明...(55)
# 13       社會  18:39      離譜！假搜索真包庇色情業　台中貪警遭搜索(3930)
# 14       3C  18:39     【GAME啥】居民招募中 《夢想星城》將...(20)
# 15       體育  18:38         王躍霖曾向賽揚投手請益　桃猿先發3搶1(16)
# 16       國際  18:37         謎底揭開　明尼蘇達州湖底客機是__(1031)
# ...

# %%
res = requests.get('http://140.115.236.11/query_tea.asp?STR=ZB105&Query=%ACd%B8%DF&MM2=2&YY2=2016&item2=%AFZ%AF%C5')
res.encoding = 'big5'
print res.text
# Out:
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=big5">
# <meta name="GENERATOR" content="Microsoft FrontPage 4.0">
# <meta name="ProgId" content="FrontPage.Editor.Document">
#
# <title>課表列印</title>
# <style>
# <!--
# .A9          { font-family: Arial; font-size: 9pt; color: #0000FF }
# -->
# </style>
# </head>
# <body>
#
#   <form method="POST" action="FIRST.ASP" name="QUERY" target="first">
#   <table border="0" width="99%" cellspacing="0" cellpadding="0">
#   <tr>
#     <td width="30%"> 年月：2016年2月 課表&nbsp;</td>
#     <td width="26%"> <p align="center"><font color="#800000"><<　依班級：ZB105　&gt;&gt;</font></td>
#     <td width="37%"> <p align="right">製成時間：2001/02/16 PM 05:43:55
#     </td>
#   </tr>
#   </table>
#   <table border="1" width="99%" bgcolor="#CAEEFF" cellspacing="0" cellpadding="0" bordercolor="#CAEEFF" bordercolorlight="#009EEA" bordercolordark="#FFFFFF" height="50" class="A9">
#   <tr>
#     <td width="6%" colspan="2" class="A9" height="30">
# ...

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload = {
    'method':'search',
    'searchMethod':'true',
    'searchTarget':'ATM',
    'hid_1':'1',
    'tenderStatus':'4,5,21,29',
    'awardAnnounceStartDate':'105/02/25',
    'awardAnnounceEndDate':'105/02/25',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'hid_2':'1',
    'hid_3':'1',
    'btnQuery':'查詢'
}
res = requests.post(url, data = playload)
soup = BeautifulSoup(res.text)
for tr in soup.select('#print_area tr')[1:-1]:
    #print tr.select('a')
    print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787067&tenderCaseNo=9786y10501
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787064&tenderCaseNo=105-02
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787056&tenderCaseNo=1042009
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787055&tenderCaseNo=M05H7230
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787054&tenderCaseNo=10510
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787053&tenderCaseNo=TRES1050105
# ...

# %%
import math
rec_number = soup.select('.T11b')
page_number = int(math.ceil(float(rec_number[0].text) /100 ))

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={}'
for page in xrange(page_number):
    print url.format(page + 1)
# Out:
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=4

# %%
page2 = url.format(2)
res2 = rs.get(page2)
soup2 = bs(res2.text)
#print soup2
#for tr in soup2.select('#print_area tr')[1:-1]:
 #   print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
    
    
    
# ??????
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-8bc06be1b468> in <module>()
#       4 #print soup2
#       5 for tr in soup2.select('#print_area tr')[1:-1]:
# ----> 6     print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
#       7
#       8
#
# IndexError: list index out of range

# %%
page2 = url.format(2)
res2 = rs.get(page2)
soup2 = bs(res2.text)
#print soup2
for tr in soup2.select('#print_area tr')[1:-1]:
    print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785587&tenderCaseNo=jmes1050224
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785589&tenderCaseNo=105004
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785598&tenderCaseNo=105001403
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785602&tenderCaseNo=120050002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785613&tenderCaseNo=1050126E
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785620&tenderCaseNo=TCGPD-CID1050007
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
aurl ='http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance'
playload ={
'method':'search',
'searchMethod':'true',
'searchTarget':'ATM',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderStatus':'4,5,21,29',
'tenderWay':'',
'awardAnnounceStartDate':'105/02/25',
'awardAnnounceEndDate':'105/02/25',
'proctrgCate':'3',
'radProctrgCate':'3',
'tenderRange':'',
'minBudget':'',
'maxBudget':'',
'item':'',
'hid_2':'1',
'gottenVendorName':'',
'gottenVendorId':'',
'hid_3':'1',
'submitVendorName':'',
'submitVendorId':'',
'location':'',
'priorityCate':'',
'isReConstruct':'',
'btnQuery':'查詢',
}
rs = requests.session()
res = rs.post(url , data = playload)
soup = bs(res.text)
#print soup
for div in soup.select('#print_area tr')[1:-1]:
    print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785585&tenderCaseNo=RDL0516002
# ...

# %%
import math
rec_number = soup.select('.T11b')
page_number = int(math.ceil(float(rec_number[0].text) /100 ))

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex={}'
for page in xrange(page_number):
    print url.format(page + 1)
# Out:
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=3
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=4

# %%
page2 = url.format(2)
res2 = rs.get(page2)
soup2 = bs(res2.text)
#print soup2
for tr in soup2.select('#print_area tr')[1:-1]:
    print 'http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:]
# Out:
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785587&tenderCaseNo=jmes1050224
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785589&tenderCaseNo=105004
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785598&tenderCaseNo=105001403
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785602&tenderCaseNo=120050002
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785613&tenderCaseNo=1050126E
# http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51785620&tenderCaseNo=TCGPD-CID1050007
# ...

# %%
with open('bit_list.txt' , 'w') as f:
    for page in xrange(page_number):
        pageurl = urlformat.format(page + 1)
        res2 = rs.get(pageurl)    
        soup2 = bs(res2.text)
        for tr in soup2.select('#print_area tr')[1:-1]:
            f.write('http://web.pcc.gov.tw/tps' + tr.select('a')[0]['href'][2:] + '\n')

# %%
dic = {}
with open('/Users/BIG DATA/Desktop/python/bit_list.txt', 'r') as f:
    for url in f.readlines():
        rearstr = url.strip().split('pkAtmMain=')
        #print rearstr[1].split('&tenderCaseNo=')
        pkatmmain, caseno = rearstr[1].split('&tenderCaseNo=')
        #print pkatmmain, caseno
        if not caseno in dic:
            dic[caseno] = 1
        else:
            print caseno
# Out:
# 105001
# 10501
# 10510
# 10505
# 10510
# 10508
# 1050006
# 10504
# 10502
# 10502
# 105-02
# 10502
# 10504
# 105-004
# A105002
# 1050122
# 1050202
# 10502
# 105003
# 10503
# 105A004
# 105008
# 10501
# 10510
# 1050129
# 10502
# 10504

# %%
print [url for url in open('bit_list.txt', 'r').readlines() if '1042009' in url]
# Out:
# ['http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51787056&tenderCaseNo=1042009\n']

# %%
import os
os.mkdir('gov1')

# %%
import time
with open('bit_list.txt', 'r') as f:
    for url in f.readlines():
        rearstr = url.strip().split('pkAtmMain=')
        pkatmmain, caseno = rearstr[1].split('&tenderCaseNo=')
        filename = 'gov1/{}_{}.txt'.format(pkatmmain, caseno)
        #print filename
        with open(filename, 'w') as f2:
            res = requests.get(url.strip())
            f2.write(res.text.encode('utf-8'))
        time.sleep(1)

# %%
res = requests.get('http://163.29.251.188/botedata/交通流量/103年度/103年度臺北市交通流量及特性調查.files/sheet001.htm')
res.encoding = 'big5'
print res.text
# Out:
# <html xmlns:o="urn:schemas-microsoft-com:office:office"
# xmlns:x="urn:schemas-microsoft-com:office:excel"
# xmlns="http://www.w3.org/TR/REC-html40">
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=big5">
# <meta name=ProgId content=Excel.Sheet>
# <meta name=Generator content="Microsoft Excel 11">
# <link id=Main-File rel=Main-File href="../103年度臺北市交通流量及特性調查.htm">
# <link rel=File-List href=filelist.xml>
# <link rel=Edit-Time-Data href=editdata.mso>
# <title>102年度臺北市交通流量及特性調查</title>
# <link rel=Stylesheet href=stylesheet.css>
# <style>
# <!--table
# 	{mso-displayed-decimal-separator:"\.";
# 	mso-displayed-thousand-separator:"\,";}
# @page
# 	{margin:1.0in .75in 1.0in .75in;
# 	mso-header-margin:.5in;
# 	mso-footer-margin:.5in;}
# ruby
# 	{ruby-align:left;}
# rt
# 	{color:windowtext;
# 	font-size:9.0pt;
# 	font-weight:400;
# 	font-style:normal;
# 	text-decoration:none;
# 	font-family:細明體, monospace;
# 	mso-font-charset:136;
# 	mso-char-type:none;
# ...

# %%
with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            print tr.select('th')[0].text.strip(),tr.select('td')[0].text.strip()
# Out:
# 機關代碼 A.21.4
# 機關名稱 衛生福利部國民健康署
# 單位名稱 衛生福利部國民健康署
# 機關地址 103臺北市大同區塔城街36號
# 聯絡人 林雅雯
# 聯絡電話 (02)25220935
# 傳真號碼 (02)25220986
# 標案案號 B1041118
# 招標方式 限制性招標(經公開評選或公開徵求)
# 決標方式 準用最有利標
# 新增公告傳輸次數 01
# 是否依據採購法第106條第1項第1款辦理 否
# 標案名稱 105年健康體重管理資訊網功能擴充及維護案
# 決標資料類別 決標公告
# 是否屬共同供應契約採購 否
# 是否屬二以上機關之聯合採購(不適用共同供應契約規定) 否
# 是否複數決標 否
# 是否共同投標 否
# 標的分類 <勞務類>
#                             93
#                             健康及社會服務
# 是否屬統包 否
# 是否應依公共工程專業技師簽證規則實施技師簽證 否
# 開標時間 104/12/11 10:30
# 原公告日期 104/11/27
#
#         	　　原公告日期係指最近1次招標公告或更正日期
# 採購金額級距 公告金額以上未達查核金額
# 辦理方式 自辦
# 限制性招標依據之法條 採購法第22條第1項第9款
# 是否適用條約或協定之採購 .gpa_shift {
# 		margin-left: 30px;
# 	}
# 	.gpa_shift2 {
# 		margin-left: 60px;
# 	}
# 	.gpa_error_msg {
# 		color:#FF0000;
# 		font-size:10pt;
# 	}
#
# 是否適用WTO政府採購協定(GPA)：
#
#
# 		否
#
#
#
#
#
# 是否適用臺紐經濟合作協定(ANZTEC)：
#
#
# 		否
#
#
#
#
#
# 是否適用臺星經濟夥伴協定(ASTEP)：
#
#
# 		否
# 預算金額是否公開 是
# 預算金額 1,865,000元
# 是否受機關補助 否
# 履約地點 臺北市(非原住民地區)
# 履約地點（含地區） 臺北市－大同區
# 是否含特別預算 否
# 歸屬計畫類別 非屬愛台十二項計畫
# ...

# %%
with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            if tr.select('th')[0].text.strip().encode('utf-8') == '機關代碼':
                print tr.select('th')[0].text.strip(),tr.select('td')[0].text.strip()
# Out:
#  機關代碼 A.21.4

# %%
with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            if tr.select('th')[0].text.strip().encode('utf-8') == '機關代碼':
                print tr.select('th')[0].text.strip(),tr.select('td')[0].text.strip()
            if tr.select('th')[0].text.strip().encode('utf-8') == '單位名稱':
                print tr.select('th')[0].text.strip(),tr.select('td')[0].text.strip()
# Out:
# 機關代碼 A.21.4
# 單位名稱 衛生福利部國民健康署

# %%
dic = {'a':1, 'b':2}
print dic['a']
# Out:
# 1

# %%
print 'a' in dic
# Out:
# True

# %%
dic = {'機關代碼':'', '單位名稱':'', '聯絡人':'', '聯絡電話':'', '傳真號碼':''}


with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            if tr.select('th')[0].text.strip().encode('utf-8') in dic :
                print tr.select('th')[0].text.strip(),tr.select('td')[0].text.strip()
# Out:
# 機關代碼 A.21.4
# 單位名稱 衛生福利部國民健康署
# 聯絡人 林雅雯
# 聯絡電話 (02)25220935
# 傳真號碼 (02)25220986

# %%
dic = {'機關代碼':'', '單位名稱':'', '聯絡人':'', '聯絡電話':'', '傳真號碼':''}


with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            if tr.select('th')[0].text.strip().encode('utf-8') in dic :
                dic[tr.select('th')[0].text.strip().encode('utf-8')] = tr.select('td')[0].text.strip()

# %%
for ele in  dic:
    print ele, dic[ele]
# Out:
# 傳真號碼 (02)25220986
# 聯絡人 林雅雯
# 單位名稱 衛生福利部國民健康署
# 機關代碼 A.21.4
# 聯絡電話 (02)25220935

# %%
dic = {'標的分類':''}


with open('gov1/51776211_B1041118.txt', 'r') as f:
    soup = bs(f.read())
    for tr in soup.select('.table_block.tender_table tr'):
        if len(tr.select('th')) > 0:
            th_name  = tr.select('th')[0].text.strip().encode('utf-8')
            td_value = tr.select('td')[0].text.strip()
            if th_name in dic:
                dic[th_name] = td_value
                
                
#               XXXXXXXX
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-135-afe6d73a3fa9> in <module>()
#       7         if len(tr.select('th')) > 0:
#       8             th_name  = tr.select('th')[0].text.strip().encode('utf-8')
# ----> 9             td_value = tr.select('td')[0].text.strip()
#      10             if th_name in dic:
#      11                 dic[th_name] = td_value
#
# IndexError: list index out of range

# %%
a='\t\t string \n\t'
print a
print repr(a)
# Out:
# 		 string
#
# '\t\t string \n\t'

# %%
a = 'adddddddddddd                              ddddddddddddddddd              \t          d d           \n '
#print a
print a.split()
print ' '.join(a.split())
print ''.join(a.split())
# Out:
# ['adddddddddddd', 'ddddddddddddddddd', 'd', 'd']
# adddddddddddd ddddddddddddddddd d d
# addddddddddddddddddddddddddddddd

# %%
from datetime import date,datetime
currenttime=datetime.now()
print type(currenttime)
print type(currenttime.strftime("%Y-%m-%d"))
# Out:
# <type 'datetime.datetime'>
# <type 'str'>

# %%
a='2014-05-03 14:00'
print type(a)
print type(datetime.strptime(a,"%Y-%m-%d %H:%M"))
# Out:
# <type 'str'>
# <type 'datetime.datetime'>

# %%
from datetime import date,datetime, timedelta
currentdt=datetime.today()
print currentdt + timedelta(days= 1)
# Out:
# 2016-02-26 20:28:42.762000

# %%
for i in range(1,31):
    print (currentdt + timedelta(days= -i)).strftime('%Y-%m-%d')
# Out:
# 2016-02-24
# 2016-02-23
# 2016-02-22
# 2016-02-21
# 2016-02-20
# 2016-02-19
# 2016-02-18
# 2016-02-17
# 2016-02-16
# 2016-02-15
# 2016-02-14
# 2016-02-13
# 2016-02-12
# 2016-02-11
# 2016-02-10
# 2016-02-09
# 2016-02-08
# 2016-02-07
# 2016-02-06
# 2016-02-05
# 2016-02-04
# 2016-02-03
# 2016-02-02
# 2016-02-01
# 2016-01-31
# 2016-01-30
# 2016-01-29
# 2016-01-28
# 2016-01-27
# 2016-01-26

# %%
import re 
m = re.match(r"(?P<FirstName>\w+) (?P<LastName>\w+)", "David Chiu") 
print m.group("FirstName"), m.group("LastName")
# Out:
# David Chiu

# %%
import re 
m = re.match(r"(\w+)@(\w+)", "david@largtidata.com") 
print m.groups()
 
m = re.match(r"(\w+)@([a-z.]+)", "david@largtidata.com") 
print m.groups() 

m = re.match(r"(\d+)\.(\d+)", "1999.5") 
print m.groups() 

m = re.match(r"(?P<first_name>\w+) (?P<last_name>\w+)", "David Chiu") 
print m.group('first_name'), m.group('last_name')
 
str1 = 'scp file.txt root@10.0.0.1:./' 
m=re.search('^scp ([\w\.]+) (\w+)@([\w\.]+):(.+)',str1) 
if m: 
    print m.group(1), m.group(2), m.group(3), m.group(4)
# Out:
# ('david', 'largtidata')
# ('david', 'largtidata.com')
# ('1999', '5')
# David Chiu
# file.txt root 10.0.0.1 ./

# %%
import re
str1 = "0912-345-678"
str2 = "0912-678444"

m = re.match(r"(\d{4}-?\d{3}-?\d{3})", str1)
print m.groups()
# print re.match(r"\d{4}-?\d{3}-?\d{3}", str2)
# Out:
# ('0912-345-678',)

# %%
#declare dictionary 
dic = {'a':100, 'b':"yes", 'c':0.98} 
print dic 

#get keys in dictionary 
print dic.keys() 

#get values in dictionary 
print dic.values() 

#get value of given key 
print dic['a'] 

#get value of given key 
print dic.get('a')

#add entry into dictionary 
dic['d'] = 'new' 
print dic 

#add entry into dictionary 
dic.update({'e':123}) 
print dic 

# iter the dictionary 
for rec in dic: 
    print rec, dic[rec]
# Out:
# {'a': 100, 'c': 0.98, 'b': 'yes'}
# ['a', 'c', 'b']
# [100, 0.98, 'yes']
# 100
# 100
# {'a': 100, 'c': 0.98, 'b': 'yes', 'd': 'new'}
# {'a': 100, 'c': 0.98, 'b': 'yes', 'e': 123, 'd': 'new'}
# a 100
# c 0.98
# b yes
# e 123
# d new
