# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt


img = cv2.imread('C:/Users/BIG DATA/Desktop/python/aaa.jpg',)
#plt.imshow(img)
im = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(im)
