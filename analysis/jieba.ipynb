# %%
#encoding='utf-8'
import jieba
import time
import re


jieba.set_dictionary('E:/text_mining/dict.txt')

s ="為節能減碳，中央今年將線上簽核目公文的目標訂在45％，但柯市府希望更上一層樓，自行設定65％的高標，但此舉引來底下局處抱怨，台北市長柯文哲今受訪表示，他認為這叫做盡力，他不贊成政策設一條線要求大家一定要這樣，但就是設一個方向讓大家努力，他認為公務員就是把目標設定在那裡死板板的，所以常造成行政上困擾。線上公文引來北市府不少局處困擾，包括社會局、勞動局和法務局，不易把民眾的紙本轉換成電子檔；另外文化局、都更處等，也常有複雜的圖檔與附件，轉成電子也有難處。柯表示，他認為應該盡力，他自己不贊成設一條線然後規定大家一定要這樣，但應該設一個範圍，讓大家在可以做到的範圍內往前進。他認為電子公文化確實對有些局處比較困難，因為基礎設備就不足，但他認為只要方向對了，剩下努力實行就可以。不要畫在那裏死板板的，常常造成行政上困擾。（陳思豪/台北報導）"
ele =  jieba.cut(s)
for e in ele:
    m = re.match(ur"[\u4e00-\u9fa5]+", e)
    if m:
        print e
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.501 seconds.
# DEBUG:jieba:Loading model cost 0.501 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 為
# 節能
# 減碳
# 中央
# 今年
# 將線
# 上
# 簽核目
# 公文
# 的
# 目標
# 訂
# 在
# 但柯
# 市府
# 希望
# 更上一層樓
# 自行
# 設定
# 的
# 高標
# 但
# 此舉
# 引來
# 底下
# 局處
# 抱怨
# 台北
# 市長
# 柯文
# 哲今
# 受訪
# 表示
# 他
# 認為
# 這
# 叫做
# 盡力
# 他
# 不
# 贊成
# 政策
# 設
# 一條線
# 要求
# 大家
# 一定
# 要
# 這樣
# 但
# 就是
# 設
# 一個
# 方向
# 讓
# 大家
# 努力
# 他
# 認為
# 公務員
# 就是
# 把
# 目標
# 設定
# 在
# 那裡
# 死板板
# 的
# 所以
# 常
# 造成
# 行政
# 上
# 困擾
# 線上
# 公文
# 引來
# 北
# 市府
# 不少
# 局處
# 困擾
# 包括
# 社會局
# 勞動局
# 和
# 法務局
# 不易
# 把民眾
# 的
# 紙本
# 轉換成
# 電子
# 檔
# 另外
# ...

# %%
import jieba
import numpy as np
import operator

lst_stop_word = [u'的',u'了',u'和',u'是',u'就',u'都',u'及',u'與',u'或',u'，',u'。','你','我','他','？','「','」']

str_content = "AlphaGo由Google旗下的英國人工智慧公司Google DeepMind開發，透過類似人類思維設計與自我學習方式，去年十月以五比零橫掃歐洲圍棋冠軍的中國棋手樊麾，首度戰勝職業圍棋手，之後水準穩定進步。但面對職業九段的李世石，被視為人工智慧十年發展以來最重大的一次挑戰。李誓要「捍衛人類尊嚴」李世石選擇黑子先下，開局時有些動搖，隨後漸入佳境，正當眾人以為李世石應能取勝時，他卻發生失誤，讓AlphaGo在約三個半小時的棋局後來居上。AlphaGo這次一改人工智慧快速度作風，第一子就思考約一分半才落子。賽前信心滿滿的李世石表示，「我非常驚訝，我沒想到竟然會輸掉比賽。」李世石認為，開賽時他犯了一個錯誤，若即時補救可能還有獲勝的機會，「我沒想到AlphaGo下得這麼好。」剩下四場比賽，將在台灣時間十日、十二日、十三日與十五日中午十二時舉行。李世石指出，AlphaGo的策略從開始就很出色，並且會出現一些人類不會下的步數，他非常驚訝，期待接下來的比賽。現年三十三歲的李世石，十二歲成為職業圍棋手後已囊括了十八個世界冠軍頭銜。"
itr_words = jieba.cut(str_content)
for word in itr_words:
    print word
# Out:
# AlphaGo
# 由
# Google
# 旗下
# 的
# 英國
# 人工智慧
# 公司
# Google
#
# DeepMind
# 開發
# ，
# 透過
# 類似
# 人類
# 思維
# 設計
# 與
# 自我
# 學習
# 方式
# ，
# 去年
# 十月
# 以五比
# 零橫掃
# 歐洲圍
# 棋冠
# 軍
# 的
# 中國
# 棋手
# 樊
# 麾
# ，
# 首度
# 戰勝
# 職業圍
# 棋手
# ，
# 之後水準
# 穩定
# 進步
# 。
# 但面
# 對
# 職業
# 九段
# 的
# 李世石
# ，
# 被視
# 為
# 人工智慧
# 十年
# 發展
# 以來
# 最
# 重大
# 的
# 一次
# 挑戰
# 。
# 李誓
# 要
# 「
# 捍衛人類
# 尊嚴
# 」
# 李世石
# 選擇
# 黑子
# 先
# 下
# ，
# 開局
# 時
# 有些
# 動搖
# ，
# 隨後漸
# 入
# 佳境
# ，
# 正當眾
# 人
# 以
# 為
# 李世石
# 應能
# 取勝時
# ，
# 他
# 卻
# 發生
# 失誤
# ，
# 讓
# AlphaGo
# 在
# 約
# 三個
# 半小時
# 的
# 棋局
# 後
# 來
# 居上
# 。
# AlphaGo
# 這次
# 一改
# 人工智慧
# 快
# 速度
# 作風
# ，
# 第一
# 子
# 就
# 思考
# 約
# 一分
# 半才
# 落子
# 。
# 賽前
# 信心
# 滿滿
# 的
# 李世石
# 表示
# ，
# 「
# 我
# 非常
# 驚訝
# ，
# 我
# 沒
# 想到
# 竟然
# 會輸
# 掉
# 比賽
# 。
# 」
# 李世石
# 認為
# ，
# 開賽
# 時
# 他
# 犯
# 了
# 一個
# 錯誤
# ，
# 若
# 即
# 時
# 補救
# 可能
# 還有
# 獲勝
# 的
# 機會
# ，
# 「
# 我
# 沒
# 想到
# AlphaGo
# 下得
# 這麼
# 好
# 。
# 」
# 剩下
# 四場
# 比賽
# ，
# 將在
# 台灣
# 時間
# 十日
# 、
# 十二日
# 、
# 十三日
# 與
# 十五日
# 中午
# 十二
# 時舉行
# 。
# 李世石
# 指出
# ，
# AlphaGo
# 的
# 策略
# 從
# ...

# %%
import json
with open('C:/Users/BIG DATA/Desktop/python/essay/json/201601.json', 'r') as f:
    for j in f.readlines(): 
        
        d =  json.loads(j)
        
        for i in range(0,len(d)):
            
            print d[i]['url'],d[i]['title'],d[i]['date'],d[i]['category'], d[i]['content'] ,d[i]['keyw'],d[i]['hitcount'],d[i]['comp']
            #報社或報紙名稱 = comp
            #新聞標題 = title
            #新聞分類 = category
            #新聞內文 = content
            #關鍵詞 = keyw
            #日期 = date (格式yyyyMMdd)
            #點擊次數 = hitcount
            #新聞連結 = url

# %%
import json
import jieba
jieba.set_dictionary('E:/text_mining/dict.txt')

jieba.load_userdict('.txt')  #
jieba.load_userdict('.txt') #
jieba.load_userdict('.txt') #
jieba.load_userdict('.txt') #


with open('C:/Users/BIG DATA/Desktop/python/essay/json/201601.json', 'r') as f:
    a=[]
    for j in f.readlines():         
        d =  json.loads(j)       
        for i in range(0,len(d)):            
            for ete in jieba.cut(d[i]['title']):
                a.append(ete)
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.483 seconds.
# DEBUG:jieba:Loading model cost 0.483 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
#print a
dic = {}
for ele in a:
    if ele not in dic:
        dic[ele] = 1 
    else:
        dic[ele] = dic[ele] + 1

# %%
import operator
swd = sorted(dic.items(), key = operator.itemgetter(1), reverse=True
for ele in swd:
    print ele[0], ele[1]
# Out:
#   7987
# 〉 3054
# 〈 3053
# 》 1041
# 南部 799
# 中部 791
# 北部 778
# 」 715
# 「 715
# 都 468
# 《 460
# 會 458
# 台北 430
# 的 375
# 、 367
# 自由 330
# ： 315
# 年 288
# 廣場 275
# ︰ 261
# 3 256
# 被 234
# 2 232
# ？ 227
# 不 217
# 了 193
# 月 187
# 大 172
# 人 171
# 1 170
# 中國 166
# 5 159
# 萬 158
# 4 150
# 台灣 143
# 陳 128
# 台 126
# 小 123
# 有 121
# ／ 117
# 國民黨 116
# 蔡 108
# 馬 108
# 再 108
# 中 106
# 是 104
# 立委 103
# 億 102
# 8 102
# 拚 102
# 在 100
# 與 96
# ！ 95
# 春節 94
# 10 94
# 日 91
# 新 91
# 好 90
# 沒 88
# 民進黨 86
# 柯 85
# 歲 84
# 到 83
# 6 82
# 總統 81
# 我 79
# 也 78
# 成 78
# 又 76
# 後 75
# 7 73
# - 71
# 遭 70
# 要 70
# 去年 68
# 美 68
# 為 66
# 【 65
# 】 65
# 元 65
# 黃 63
# 今 63
# 男 61
# 前 59
# 掃街 59
# 搶 59
# 台南 58
# 9 58
# ? 58
# 今年 58
# 選舉 58
# 小英 57
# 就 57
# 女 57
# 談 56
# 看 56
# 送 56
# … 55
# 高 55
# 逾 54
# 打 54
# 愛 52
# 國 52
# 12 52
# 投票 52
# 將 51
# 推 50
# 議員 50
# 催票 50
# ， 49
# 徵文 49
# P 48
# / 48
# 票 48
# 當 47
# 新聞 47
# 開放 47
# 最後 46
# 國際 46
# 英文 46
# 市府 46
# 你 46
# 天 46
# 愛情 45
# 健康 45
# 挺 44
# 多 44
# 經濟 44
# 高雄 44
# ...

# %%
#encoding='utf-8'

import jieba
import jieba.analyse
import jieba.posseg as pseg  

jieba.set_dictionary('E:/text_mining/dict.txt')
jieba.load_userdict('E:/text_mining/userdict.txt')  #
jieba.load_userdict('E:/text_mining/words.dic') #
jieba.load_userdict('E:/text_mining/negative.txt') #
jieba.load_userdict('E:/text_mining/positive.txt') #

jieba.analyse.set_stop_words("E:/text_mining/stop_words.txt") #停用詞
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.497 seconds.
# DEBUG:jieba:Loading model cost 0.497 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
#encoding='utf-8'
import pymongo
from pymongo import MongoClient
import jieba
import jieba.analyse
import jieba.posseg as pseg  

jieba.set_dictionary('E:/text_mining/dict.txt')
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #
#jieba.load_userdict('E:/text_mining/negative.txt') #
#jieba.load_userdict('E:/text_mining/positive.txt') #

jieba.analyse.set_stop_words("E:/text_mining/stop_words.txt") #停用詞




client = MongoClient() 
database = client["news"]
test2 = database["news"]

dic = {}
for post in test2.find():
    #print post['title']
    for ele in jieba.cut(post["content"]):
        if ele not in dic:                
            dic[ele] = 1 
        else:
            dic[ele] = dic[ele] + 1
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.455 seconds.
# DEBUG:jieba:Loading model cost 0.455 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
#encoding='utf-8'
from operator import itemgetter
import re
swd = sorted(dic.items(), key = itemgetter(1), reverse=True)

with open('keyword.txt', "w" ,) as f:
    for ele in swd:
        if re.match(u'[\u4e00-\u9fa5]+', ele[0]) and ele[1] >=20 and len(ele[0])>=2:
            pass
            #print ele[0], ele[1]
            f.write(ele[0].encode('utf-8') + '\n')
f.close()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------

# %%
#encoding='utf-8'
import jieba
import re
import jieba.analyse


jieba.set_dictionary('E:/text_mining/dict.txt')
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #


jieba.analyse.set_stop_words("E:/text_mining/stop_words.txt")


s ="新北市長朱立倫13日出席「新北市學童護眼方案」擴大實施記者會，除感謝眼科醫師學會協助保護小朋友的靈魂之窗，呼籲小朋友減少3C產品的使用，家長也需要一同來努力，幫助小朋友從小養成良好的護眼習慣。朱立倫表示，3C產品的盛行確實影響了小朋友的視力，近視年齡也有提前的趨勢，隨著年齡增長有惡化的情形，保護孩子的視力是必要且需要立刻進行。指104年已針對國小二年級全部學童免費視力檢查，今年則擴大納入一、二、三年級，約有10萬學童受惠。衛生局表示，104年結合公私部門資源，包括衛生局、教育局、學校、眼科醫學會及眼科醫療院所推動「新北市學童護眼方案」，提供全市國小二年級學生免費專業視力檢查，共有16,174位學童接受檢查，發現約30位學童有高度近視，由醫師當場提醒家長重視孩子的視力健康。衛生局指出，目前正製作新的「護眼筆記」小手冊，本(4)月起寄發給學校，再由校方於9月開學後發給學童，只要持小手冊到合約醫療院所，就享有一次專業的視力檢查服務，家長無需繳納任何費用。"
a =  jieba.lcut(s)
dic = {}
for ele in a:
    if ele not in dic:                
        dic[ele] = 1 
    else:
        dic[ele] = dic[ele] + 1
        
quanzhong=jieba.analyse.extract_tags(s,topK=30)
print "基于 TF-IDF 算法的關鍵字抽取  "," / ".join(quanzhong)


#tags = jieba.analyse.textrank(s,30)
#print "基于 TextRank 算法的關鍵字抽取"," / ".join(tags)
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.552 seconds.
# DEBUG:jieba:Loading model cost 0.552 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 基于 TF-IDF 算法的關鍵字抽取   學童 / 視力 / 檢查 / 護眼 / 小朋友 / 家長 / 衛生局 / 眼科 / 3C產品 / 免費 / 保護 / 二年級 / 醫療院所 / 年齡 / 學校 / 新北市 / 手冊 / 104 / 醫師 / 國小 / 納入 / 感謝 / 醫學會 / 呼籲 / 也有 / 30 / 養成 / 再由 / 繳納 / 習慣
# 基于 TextRank 算法的關鍵字抽取 孩子 / 眼科 / 盛行 / 小朋友 / 提醒 / 情形 / 教育局

# %% [markdown]
# # 加入停用詞 (測試)

# %%
#encoding='utf-8'
import pymongo
from pymongo import MongoClient
import jieba
import jieba.analyse
import jieba.posseg as pseg  
import io

jieba.set_dictionary('E:/text_mining/dict.txt')
jieba.load_userdict('E:/text_mining/dict_keyw_new.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #
#jieba.load_userdict('E:/text_mining/negative.txt') #
#jieba.load_userdict('E:/text_mining/positive.txt') #
stoplist = []
with io.open('E:/text_mining/stop_words.txt','r',encoding = 'utf-8') as f:
    for line in f.readlines():
        stoplist.append(line.strip('\n'))
    


client = MongoClient() 
database = client["news"]
test2 = database["news"]

dic = {}
for post in test2.find():
    #print post['title']
    for ele in jieba.cut(post["content"]):
        if not ele in stoplist:
            if ele not in dic:
                dic[ele] = 1 
            else:
                dic[ele] = dic[ele] + 1
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.526 seconds.
# DEBUG:jieba:Loading model cost 0.526 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e95263ea1af5> in <module>()
#      26 for post in test2.find():
#      27     #print post['title']
# ---> 28     for ele in jieba.cut(post["content"]):
#      29         if not ele in stoplist:
#      30             if ele not in dic:
#
# ...

# %%
#encoding='utf-8'
import jieba
import time
import re


jieba.set_dictionary('E:/text_mining/dict.txt')

s ="為節能減碳,中央今年將線上簽核目公文的目標訂在45％，但柯市abc府希望更上一層樓，自行設定65％的高標，但此舉引來底下局處抱怨，台北市長柯文哲今受訪表示，他認為這叫做盡力，他不贊成政策設一條線要求大家一定要這樣，但就是設一個方向讓大家努力，他認為公務員就是把目標設定在那裡死板板的，所以常造成行政上困擾。線上公文引來北市府不少局處困擾，包括社會局、勞動局和法務局，不易把民眾的紙本轉換成電子檔；另外文化局、都更處等，也常有複雜的圖檔與附件，轉成電子也有難處。柯表示，他認為應該盡力，他自己不贊成設一條線然後規定大家一定要這樣，但應該設一個範圍，讓大家在可以做到的範圍內往前進。他認為電子公文化確實對有些局處比較困難，因為基礎設備就不足，但他認為只要方向對了，剩下努力實行就可以。不要畫在那裏死板板的，常常造成行政上困擾。（陳思豪/台北報導）"
ele =  jieba.cut(s)
for e in ele:
    m =re.sub(r'\W+', '', e)
    if m:
        print e
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.508 seconds.
# DEBUG:jieba:Loading model cost 0.508 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 45
# abc
# 65

# %%
#encoding='utf-8'
import jieba
import time
import re


jieba.set_dictionary('E:/text_mining/dict.txt')

s ="為節能減碳,中央今年將線上簽核目公文的目標訂在45％，但柯市abc府希望更上一層樓，自行設定65％的高標，但此舉引來底下局處抱怨，台北市長柯文哲今受訪表示，他認為這叫做盡力，他不贊成政策設一條線要求大家一定要這樣，但就是設一個方向讓大家努力，他認為公務員就是把目標設定在那裡死板板的，所以常造成行政上困擾。線上公文引來北市府不少局處困擾，包括社會局、勞動局和法務局，不易把民眾的紙本轉換成電子檔；另外文化局、都更處等，也常有複雜的圖檔與附件，轉成電子也有難處。柯表示，他認為應該盡力，他自己不贊成設一條線然後規定大家一定要這樣，但應該設一個範圍，讓大家在可以做到的範圍內往前進。他認為電子公文化確實對有些局處比較困難，因為基礎設備就不足，但他認為只要方向對了，剩下努力實行就可以。不要畫在那裏死板板的，常常造成行政上困擾。（陳思豪/台北報導）"
ele =  jieba.cut(s)
for e in ele:
    m =re.match(ur'^[\u4e00-\u9fa5_a-zA-Z0-9]+', e)
    if m:
        print e
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.510 seconds.
# DEBUG:jieba:Loading model cost 0.510 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 為
# 節能
# 減碳
# 中央
# 今年
# 將線
# 上
# 簽核目
# 公文
# 的
# 目標
# 訂
# 在
# 45
# 但
# 柯市
# abc
# 府
# 希望
# 更上一層樓
# 自行
# 設定
# 65
# 的
# 高標
# 但
# 此舉
# 引來
# 底下
# 局處
# 抱怨
# 台北
# 市長
# 柯文
# 哲今
# 受訪
# 表示
# 他
# 認為
# 這
# 叫做
# 盡力
# 他
# 不
# 贊成
# 政策
# 設
# 一條線
# 要求
# 大家
# 一定
# 要
# 這樣
# 但
# 就是
# 設
# 一個
# 方向
# 讓
# 大家
# 努力
# 他
# 認為
# 公務員
# 就是
# 把
# 目標
# 設定
# 在
# 那裡
# 死板板
# 的
# 所以
# 常
# 造成
# 行政
# 上
# 困擾
# 線上
# 公文
# 引來
# 北
# 市府
# 不少
# 局處
# 困擾
# 包括
# 社會局
# 勞動局
# 和
# 法務局
# 不易
# 把民眾
# 的
# 紙本
# ...

# %%
#encoding='utf-8'
import jieba
import time
import re
jieba.set_dictionary('E:/text_mining/dict.txt')

s='\u3010\u653f\u6cbb\u4e2d\u5fc3\u2571\u53f0\u5317\u5831\u5c0e\u3011\u7e3d\u7d71\u5e9c\u6628\u6df1\u59
1c\u767c\u5e03\u65b0\u805e\u7a3f\u5ba3\u5e03\uff0c\u884c\
u653f\u9662\u9577\u5167\u5b9a\u5c07\u7531\u884c\u653f\u9662\u526f\u9662\u9577\u6c5f\u5b9
c\u6a3a\u51fa\u4efb\uff0c\u884c\u653f\u9662\u526f\u9662\u9577\u5167\u5b9a\u5c07\u7531\u4ea4\u901a\u90e
8\u9577\u6bdb\u6cbb\u570b\u51fa\u4efb\uff0c\u73fe\u4efb\u884c\u653f\u9662\u9577\u9673\u51b2\u5c07\u8f
49\u4efb\u7e3d\u7d71\u5e9c\u8cc7\u653f\u3002\u9673\u51b2\u6628\u5929\u6df1\u591c\u624d\u8207\u5a92\u9a
d4\u540c\u6b65\u5f97\u77e5\u7e3d\u7d71\u5e9c\u5ba3\u5e03\u9019\u9805\u8a0a\u606f\uff0c
string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）]+".decode("utf8"), "".decode("utf8"),s)
print string
# Out:
#   File "<ipython-input-8-c232020fc1a9>", line 7
#     s='\u3010\u653f\u6cbb\u4e2d\u5fc3\u2571\u53f0\u5317\u5831\u5c0e\u3011\u7e3d\u7d71\u5e9c\u6628\u6df1\u591c\u767c\u5e03\u65b0\u805e\u7a3f\u5ba3\u5e03\uff0c\u884c\u653f\u9662\u9577\u5167\u5b9a\u5c07\u7531\u884c\u653f\u9662\u526f\u9662\u9577\u6c5f\u5b9c\u6a3a\u51fa\u4efb\uff0c\u884c\u653f\u9662\u526f\u9662\u9577\u5167\u5b9a\u5c07\u7531\u4ea4\u901a\u90e8\u9577\u6bdb\u6cbb\u570b\u51fa\u4efb\uff0c\u73fe\u4efb\u884c\u653f\u9662\u9577\u9673\u51b2\u5c07\u8f49\u4efb\u7e3d\u7d71\u5e9c\u8cc7\u653f\u3002\u9673\u51b2\u6628\u5929\u6df1\u591c\u624d\u8207\u5a92\u9ad4\u540c\u6b65\u5f97\u77e5\u7e3d\u7d71\u5e9c\u5ba3\u5e03\u9019\u9805\u8a0a\u606f\uff0c
# ...
