# %%
import time

tStart=time.time() #計算所需時間(計時開始)
tEnd = time.time() #記時(時間結束)
  
print ' cost {} s'.format(tEnd-tStart)    #將經過時間print 出來
# Out:
#  cost 0.0 s

# %%
import jieba
from pymongo import MongoClient 
import time
tStart=time.time() #計算所需時間(計時開始)

jieba.set_dictionary('E:/text_mining/dict.txt')  #切換至中文繁體字庫
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #

client = MongoClient('10.120.28.14',27017)
database = client['test']
collection =database['test5']


negative_set=set()
positive_set=set()

negative_write=set()
positive_write=set()

f=open('E:/text_mining/negative.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in negative_set:
        negative_set.add(word)
f.close()


f=open('E:/text_mining/positive.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in positive_set:
        positive_set.add(word)
f.close()

a=0
b=0
for post in collection.find(): 
    summary = post['content']
    content=jieba.cut(summary)
    for word in content:
        #print word
        if word.encode('utf-8') in negative_set:
            a=a+1
            negative_write.add(word.encode('utf-8'))
        if word.encode('utf-8') in positive_set:
            b=b+1
            positive_write.add(word.encode('utf-8'))
    break
print '負向', a
print '正向', b

negative=open('negative_word.txt','w')
for word in negative_write:
    negative.write(word+'\n')
negative.close()

positive=open('positive_word.txt','w')
for word in positive_write:
    positive.write(word+'\n')
positive.close()

tEnd = time.time() #記時(時間結束)
  
print ' 花了 {} s'.format(tEnd-tStart)    #將經過時間print 出來
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.528 seconds.
# DEBUG:jieba:Loading model cost 0.528 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 負向 21
# 正向 49
#  花了 7.33200001717 s

# %%
import jieba
from pymongo import MongoClient 


jieba.set_dictionary('E:/text_mining/dict.txt')  #切換至中文繁體字庫
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #

client = MongoClient('10.120.28.14',27017)
database = client['test']
collection =database['test5']


negative_set=set()
positive_set=set()

negative_write=set()
positive_write=set()

f=open('E:/text_mining/negative.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in negative_set:
        negative_set.add(word)
f.close()


f=open('E:/text_mining/positive.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in positive_set:
        positive_set.add(word)
f.close()

a=0
b=0
for post in collection.find(): 
    summary = post['content']
    content=jieba.cut(summary)
    for word in content:
        #print word
        if word.encode('utf-8') in negative_set:
            a=a+1
            negative_write.add(word.encode('utf-8'))
        if word.encode('utf-8') in positive_set:
            b=b+1
            positive_write.add(word.encode('utf-8'))
    break

print '負向共有',a,'個詞'
print '---------------------'
for word in negative_write:
    print word
    
print '\n'
    
print '正向共有',b,'個詞'
print '---------------------'
for word in positive_write:
    print word
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.525 seconds.
# DEBUG:jieba:Loading model cost 0.525 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 負向共有 21 個詞
# ---------------------
# 下台
# 表面工夫
# 不應
# 嚴肅
# 迫切需要
# 隨便
# 爭議
# 歷史
# 不在
# 撤銷
# 質疑
# 不是
# 挪用
# 否則
# 偏離
#
#
# 正向共有 49 個詞
# ---------------------
# 努力
# 計畫
# 必當
# 作為
# 呈現
# 是為了
# 善用
# 典範
# 多元
# 創新
# 推廣
# 應用
# 透過
# 更多
# 風光
# 就可
# 應該
# 預計
# 宣導
# 只要
# 資源
# 增加
# 累積
# 表示
# 必定
# 快馬加鞭
# 打造
# 舉辦
# 都應
# 投注
# 籌辦
# 設法
# 熱鬧
# 續聘

# %%
import jieba
from pymongo import MongoClient 
import time
tStart=time.time() #計算所需時間(計時開始)

jieba.set_dictionary('E:/text_mining/dict.txt')  #切換至中文繁體字庫
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #

client = MongoClient('10.120.28.14',27017)
database = client['test']
collection =database['test5']


negative_set=set()
positive_set=set()
neg_word_count =0
pos_word_count =0
negative_write=set()
positive_write=set()

f=open('E:/text_mining/negative.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in negative_set:
        negative_set.add(word)
f.close()


f=open('E:/text_mining/positive.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in positive_set:
        positive_set.add(word)
f.close()


obj = collection.find()
summary = obj[551]['content']
content=jieba.cut(summary)

for word in content:
    #print word
    if word.encode('utf-8') in negative_set:
        neg_word_count=neg_word_count+1
        negative_write.add(word.encode('utf-8'))
    if word.encode('utf-8') in positive_set:
        pos_word_count=pos_word_count+1
        positive_write.add(word.encode('utf-8'))

print '負向詞共有',neg_word_count,'個'
print '---------------------'
for word in negative_write:
    print word
    
print '\n'
    
print '正向詞共有',pos_word_count,'個'
print '---------------------'
for word in positive_write:
    print word

    
print '\n'
tEnd = time.time() #記時(時間結束)
print ' 花了 {} s'.format(tEnd-tStart)    #將經過時間print 出來
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.552 seconds.
# DEBUG:jieba:Loading model cost 0.552 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 負向詞共有 20 個
# ---------------------
# 不僅
# 脅迫
# 毒打
# 不料
# 被告
# 最後
# 犯下
# 不能
# 超過
# 不利
# 缺錢
# 逃亡
# 失敗
# 被害人
# 追訴
# 審判
# 未果
#
#
# 正向詞共有 17 個
# ---------------------
# 機警
# 行動
# 加計
# 依法
# 直到
# 有利
# 法律
# 再度
# 所幸
# 實際上
# 最有利
# 原則
# 做出
# 表示
# 指出
#
#
#  花了 7.35000014305 s

# %%
 {'pos':pos_result,'neg':neg_result}

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %%
#把使用的套件都匯入
import re
from pymongo import MongoClient 
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re
import jieba
jieba.set_dictionary('E:/text_mining/dict.txt')  #切換至中文繁體字庫
jieba.load_userdict('E:/text_mining/dict_keyw.txt')  #
jieba.load_userdict('E:/text_mining/dict_cbdic.txt')  #
#預設就是自己
client = MongoClient('10.120.28.14',27017)
database = client['test']
collection =database['test4']
# Out:
# Building prefix dict from E:\text_mining\dict.txt ...
# DEBUG:jieba:Building prefix dict from E:\text_mining\dict.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u144803eaa96482ea338b54ad8c7f9634.cache
# Loading model cost 0.533 seconds.
# DEBUG:jieba:Loading model cost 0.533 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
import time
tic = time.clock()

title=[]
content =[]
#拿資料
for post in collection.find(): 
    summary = post['content']
    content.append(jieba.cut(summary))
    title.append(post['title'])
#總文章數量
print "文章數:",len(title)
toc = time.clock()
print "執行時間:",(toc - tic)
# Out:
# 文章數: 6287
# 執行時間: 0.166169468866

# %%
for i in content[1]:
    print i
# Out:
# 〔
# 記者
# 林曉
# 雲
# ／
# 台北
# 報導
# 〕
# 在
# 看守內閣
# 期間
# ，
# 教育部長
# 吳思華
# 花起
# 上
# 千萬元
# 的
# 公帑
# 毫不手軟
# ！
# 今天是
# 新閣揆
# 張善政
# 續聘
# 教長
# 的
# 首日
# ，
# 教育部
# 快馬加鞭
# 籌辦
# 教育
# 大會師
# 「
# 偏鄉教育
# 、
# 教育
# 創新
# 」
# 宣導
# 活動
# ，
# 立委
# 鄭麗君
# 追查
# 揭露
# ，
# 教育部
# 竟
# 挪用
# 原應
# 投注
# 偏鄉
# 教學
# 的
# 「
# 偏鄉
# 數位
# 應用
# 推動
# 計畫
# 」
# 預算
# ，
# 加上
# 教育部
# 文宣
# 預算
# ，
# 共
# 砸
# 一千五百多
# 萬元
# 「
# 大手筆
# 宣傳
# 政績
# 」
# ，
# 預計
# 四月
# 在
# 「
# 台北市
# 」
# 華山文創園區
# 舉辦
# 實體
# 展演
# 、
# 新
# 拍
# 十三
# 支
# 電視節目
# 、
# 把
# 各縣市
# 現成
# 教育
# 影片
# 上網
# 等
# ，
# 立委
# 質疑
# ，
# 這是
# 「
# 以
# 偏鄉教育
# 之名
# ，
# 行
# 部長
# 個人
# 行銷
# 之實
# 」
# 。
# 鄭麗君
# 表示
# ，
# 馬政府
# 為做
# 卸任
# 政績
# 偏離
# 教育
# 本業
# ，
# 教育
# 大會師
# 就是
# 政績
# 宣傳
# ，
# 原
# 不在
# 預算內
# ，
# 去年底
# 突然
# 要求
# 教育部
# 設法
# 找錢
# ，
# 竟自
# 「
# 偏鄉
# 數位
# 應用
# 推動
# 計畫
# 」
# 有限
# 預算
# 中
# 挪用
# 。
# 偏鄉
# 教學
# 最
# 迫切需要
# 就是
# 人力
# 經費
# 等
# 更多
# 資源
# 及
# 結構
# 的
# 改革
# ，
# 不是
# 把
# 基層
# 教師
# 的
# 努力
# 作為
# 教育部
# 自己
# 政績
# ，
# 卻還
# 挪用
# 偏鄉教育
# 預算
# 去
# 作宣傳
# ，
# 相信
# 偏鄉孩子
# 與
# 家長
# 必定
# 不
# 認同
# ，
# 奉勸
# 吳部長
# 懸崖勒馬
# ，
# 否則
# 立院
# 必當
# 究責
# 。
# 全國
# 家長
# 團體
# 聯盟
# 理事長
# 吳福濱
# 表示
# ，
# 教育經費
# 是
# 民脂民膏
# ，
# 教育
# 大會師
# 卻
# 像是
# 為
# 包裝
# 吳
# 任內
# 政績
# 而花
# 公帑
# ，
# 去年
# 好不容易
# 爭取
# 教育經費
# 增加
# 一百廿
# 億元
# ，
# 不是
# 讓
# 教長
# 隨便
# 花
# ，
# 每任
# 部長
# 都應
# 重視
# 偏鄉
# ，
# 迄今
# 成果
# 是
# 累積
# 來的
# ，
# 不應
# 做
# 表面工夫
# 。
# 全國
# 教師
# 總工會
# 副秘書長
# 羅德
# 水
# 表示
# ，
# 偏鄉教育
# 應該
# 嚴肅
# 面對
# ，
# 不
# 應用
# 熱鬧
# 活動
# 辦理
# ，
# 且
# 趕在
# 看守
# 教長
# 下
# 台前
# 舉辦
# ，
# 會
# 更讓人
# 質疑
# 是
# 花
# 公帑
# 打造
# 部長
# 畢展秀
# 。
# 本報
# 曾
# 獨家報導
# 教育
# 大會師
# 遭質疑
# 是為了
# 吳思華
# 平反
# 個人
# 歷史
# 定位
# 而辦
# ，
# 立委
# 管碧玲
# 直批吳
# 只要
# 撤銷
# 爭議
# 的
# 黑箱
# 微調
# 課綱
# 就可
# 風光
# 下台
# ，
# 卻
# 花上
# 千萬元
# 為
# 自己
# 政績
# 抹粉
# 「
# 太扯
# 」
# ；
# 立法院
# 教育
# 委員會
# 也
# 提醒
# 吳思華
# 應
# 善用
# 公帑
# 。
# 但
# 吳思華
# 堅持
# 要
# 辦展
# 、
# 強調
# 要
# 讓
# 偏鄉
# 教師
# 的
# 努力
# 被
# 看見
# ；
# 教育部
# 則
# 表示
# ，
# 是要
# 推廣教育
# 故事
# 及
# 創新
# 典範
# 事蹟
# ，
# 讓
# 教師
# 與
# 學生
# 努力
# 成果
# ，
# 透過
# 多元
# 媒體
# 管道
# 呈現
# 給
# 社會
# ，
# 且要
# 以
# 網路行銷
# 國內外
# 。
# 教育部
# 籌辦
# 教育
# 大會師
# 宣導
# 活動
# ，
# 挪用
# 「
# 偏鄉
# 數位
# 應用
# 推動
# 計畫
# 」
# 預算
# ，
# 立委
# 質疑
# 「
# 以
# 偏鄉教育
# 之名
# ，
# 行
# 部長
# 個人
# 行銷
# 之實
# 」
# 。
# 圖為
# 去年
# 教育部長
# 吳思華
# 下鄉
# 訪視
# 偏鄉學校
# ，
# 變身
# 趕鴨人
# 。
# （
# 資料
# 照
# ）
# 教育
# 大會師
# 活動項目
# 與
# 費用
# 四月
# 在
# 北
# 市辦
# 教育
# 大會師
# 教團
# 批花
# 公帑
# 辦
# 部長
# 畢
# 展教
# 部稱
# 推廣
# 師生
# 創新
# 事蹟

# %%
negative_set=set()
positive_set=set()

f=open('E:/text_mining/negative.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in negative_set:
        negative_set.add(word)
f.close()

f=open('E:/text_mining/positive.txt','r')
for word in f.readlines():
    word=word.strip()
    if word not in positive_set:
        positive_set.add(word)
f.close()

# %%
tStart=time.time() #計算所需時間(計時開始)

neg_write=[]
pos_write=[]

for n in range(0,6287):  #迴圈參考上面的總文章數

    neg_word_count =0
    pos_word_count =0

    for word in content[n]:
        #print word
        if word.encode('utf-8') in negative_set:
            neg_word_count=neg_word_count+1
        if word.encode('utf-8') in positive_set:
            pos_word_count=pos_word_count+1
    neg_write.append(neg_word_count)
    pos_write.append(pos_word_count)



tEnd = time.time() #記時(時間結束)
  
print ' 花了 {} s'.format(tEnd-tStart)    #將經過時間print 出來
# Out:
#  花了 13.0950000286 s

# %%
print pos_write
# Out:
# [14, 0, 53, 43, 23, 23, 28, 56, 48, 43, 30, 25, 65, 22, 39, 46, 21, 15, 31, 19, 25, 24, 25, 18, 17, 10, 23, 25, 26, 24, 9, 6, 3, 15, 9, 3, 6, 7, 34, 36, 17, 30, 21, 24, 31, 21, 24, 36, 35, 44, 19, 23, 29, 24, 29, 24, 32, 39, 26, 21, 33, 8, 41, 32, 34, 22, 21, 22, 26, 33, 24, 14, 25, 40, 8, 38, 38, 29, 10, 35, 26, 7, 13, 21, 17, 35, 20, 13, 13, 33, 28, 9, 9, 10, 31, 32, 10, 23, 19, 61, 31, 29, 106, 9, 6, 7, 37, 25, 18, 43, 45, 36, 19, 45, 38, 37, 34, 0, 30, 21, 22, 78, 37, 96, 42, 89, 89, 62, 54, 46, 48, 47, 30, 15, 31, 131, 13, 38, 54, 22, 27, 47, 16, 30, 26, 60, 35, 44, 33, 50, 47, 34, 22, 35, 51, 24, 40, 42, 36, 12, 19, 10, 36, 30, 45, 45, 87, 2, 112, 14, 32, 29, 65, 26, 19, 28, 26, 15, 24, 29, 14, 18, 39, 10, 12, 25, 13, 16, 27, 4, 14, 30, 13, 25, 17, 12, 13, 15, 6, 9, 11, 8, 10, 9, 20, 9, 23, 18, 22, 12, 12, 11, 28, 21, 27, 52, 23, 25, 6, 26, 61, 61, 100, 127, 88, 36, 24, 24, 33, 16, 46, 41, 0, 9, 63, 41, 115, 44, 32, 28, 27, 57, 17, 26, 35, 70, 41, 48, 27, 26, 10, 13, 20, 9, 37, 41, 25, 5, 15, 30, 26, 10, 17, 40, 61, 37, 57, 15, 10, 4, 14, 12, 12, 6, 17, 7, 1, 2, 11, 3, 9, 39, 37, 25, 31, 27, 15, 41, 30, 38, 34, 25, 33, 22, 24, 23, 12, 16, 12, 23, 53, 22, 46, 43, 30, 17, 16, 17, 17, 24, 33, 33, 24, 56, 25, 13, 22, 30, 35, 29, 31, 27, 42, 28, 17, 18, 15, 17, 36, 19, 36, 28, 18, 17, 29, 34, 12, 28, 11, 32, 35, 27, 10, 30, 26, 32, 33, 42, 24, 11, 14, 29, 21, 26, 26, 15, 44, 16, 21, 30, 28, 45, 36, 43, 9, 35, 21, 37, 35, 22, 31, 18, 19, 24, 62, 38, 24, 21, 20, 45, 44, 22, 39, 26, 24, 27, 28, 45, 14, 11, 17, 33, 25, 40, 3, 8, 12, 8, 28, 8, 47, 43, 57, 29, 0, 23, 25, 29, 27, 98, 28, 22, 60, 78, 46, 43, 13, 33, 38, 7, 22, 54, 63, 13, 9, 21, 42, 28, 34, 41, 27, 21, 48, 37, 19, 34, 13, 32, 45, 45, 23, 37, 34, 15, 17, 1, 38, 3, 40, 30, 48, 8, 22, 33, 31, 5, 21, 28, 5, 27, 34, 27, 23, 32, 17, 25, 25, 4, 14, 9, 29, 36, 23, 20, 16, 13, 9, 10, 8, 8, 21, 7, 12, 28, 15, 7, 15, 12, 31, 19, 30, 10, 16, 30, 23, 19, 27, 18, 6, 18, 18, 45, 39, 12, 13, 45, 22, 23, 155, 72, 16, 47, 61, 46, 74, 1, 60, 23, 9, 41, 34, 39, 47, 52, 33, 26, 48, 44, 19, 54, 22, 21, 66, 43, 30, 17, 20, 35, 32, 48, 27, 43, 13, 33, 18, 11, 41, 9, 16, 19, 3, 17, 10, 28, 11, 19, 18, 9, 12, 18, 8, 2, 17, 4, 6, 1, 2, 40, 39, 34, 29, 20, 37, 30, 27, 29, 66, 49, 38, 68, 57, 46, 22, 14, 37, 20, 24, 15, 11, 21, 11, 42, 7, 17, 39, 27, 26, 12, 15, 43, 43, 28, 37, 29, 28, 21, 59, 24, 29, 24, 13, 36, 34, 19, 19, 27, 21, 16, 36, 35, 23, 41, 14, 27, 41, 28, 11, 9, 24, 12, 22, 18, 22, 19, 18, 17, 36, 15, 22, 13, 41, 22, 45, 31, 29, 38, 40, 34, 30, 35, 38, 55, 19, 41, 34, 14, 50, 28, 31, 42, 12, 15, 40, 37, 33, 9, 17, 20, 77, 24, 25, 34, 29, 10, 19, 28, 31, 47, 61, 21, 24, 25, 26, 21, 0, 43, 21, 28, 48, 30, 56, 32, 31, 106, 49, 28, 44, 28, 30, 54, 43, 19, 20, 35, 41, 61, 32, 35, 8, 33, 17, 52, 35, 21, 30, 28, 31, 21, 21, 9, 50, 31, 30, 28, 33, 15, 34, 19, 43, 30, 41, 38, 22, 24, 15, 17, 3, 51, 22, 25, 12, 25, 40, 12, 26, 44, 22, 30, 21, 17, 27, 27, 14, 49, 15, 13, 26, 13, 14, 22, 12, 33, 8, 8, 9, 18, 2, 31, 9, 8, 26, 11, 8, 10, 15, 9, 11, 5, 20, 13, 29, 20, 26, 20, 37, 33, 48, 38, 30, 7, 74, 43, 6, 21, 17, 12, 64, 85, 37, 74, 37, 109, 21, 20, 16, 47, 49, 3, 9, 33, 128, 47, 61, 41, 50, 74, 54, 9, 35, 29, 45, 37, 17, 38, 24, 20, 21, 24, 30, 32, 19, 20, 10, 12, 12, 22, 12, 33, 15, 8, 20, 12, 50, 14, 53, 17, 17, 25, 7, 24, 12, 5, 19, 5, 9, 9, 3, 12, 6, 7, 9, 1, 30, 34, 39, 36, 31, 29, 25, 13, 16, 21, 54, 22, 17, 8, 39, 27, 41, 20, 7, 16, 28, 24, 7, 38, 22, 27, 31, 33, 39, 24, 21, 17, 38, 28, 64, 24, 46, 37, 22, 12, 44, 41, 45, 23, 50, 21, 28, 30, 42, 18, 29, 31, 27, 34, 38, 40, 21, 12, 21, 23, 27, 22, 35, 19, 41, 44, 10, 4, 43, 19, 26, 43, 35, 28, 37, 22, 11, 41, 20, 18, 28, 18, 36, 21, 24, 42, 30, 29, 51, 26, 29, 33, 19, 56, 29, 29, 28, 40, 54, 28, 34, 34, 34, 29, 32, 31, 3, 5, 8, 14, 8, 9, 19, 22, 25, 25, 48, 15, 40, 43, 16, 25, 9, 24, 26, 0, 39, 25, 25, 28, 48, 48, 16, 41, 39, 38, 52, 26, 43, 32, 49, 39, 9, 50, 8, 9, 51, 56, 37, 20, 35, 27, 14, 28, 53, 31, 32, 14, 13, 49, 42, 29, 25, 34, ...

# %%
import time
tStart=time.time() #計算所需時間(計時開始)

obj = collection.find()  #這行一定要加

for i in range(0,6287):  #迴圈參考上面的總文章數
    collection.update({"title":obj[i]["title"]},{"$set":{"pos":pos_write[i],"neg":neg_write[i]}}) #collection.update即可

tEnd = time.time() #記時(時間結束)
  
print ' 花了 {} s'.format(tEnd-tStart)    #將經過時間print 出來
# Out:
#  花了 16.4819998741 s
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
